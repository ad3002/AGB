# %% [markdown]
# <a href="https://colab.research.google.com/github/ad3002/AGB/blob/master/lectures/Lecture1_Intro1_basic_linux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd - where am I?
whoami - who am I?
ls - show files
cd - change directory
cd PATH
cd .
cd ..
cd ~
cd -
mkdir
touch - create emtpy file
rm
rm -r
rm -rf
rmdir
cat
less
more
nano
apt install tree
tree
echo

# %%
# !pwd
# Out:
# /content/sample_data

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
# !touch .hidden.txt

# %%
# !rm .hidden.txt

# %%
# !cat sample_data/README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
# !tree
# Out:
# .
# ├── hidden.txt
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 1 directory, 7 files

# %%
# !rm -rf sample_data

# %%
# !ls

# %%
# !pwd
# Out:
# /content

# %%
# !touch 1

# %%
# !ls
# Out:
# 1

# %%
# !rm 1
# Out:
# rm: cannot remove '1': No such file or directory

# %%
# !pwd
# Out:
# '/content'

# %%
# !touch my_file.txt

# %%
# !ls
# Out:
# my_file.txt

# %%
# !tree
# Out:
# /bin/bash: line 1: tree: command not found

# %%
# !sudo apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (44.8 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# ...

# %%
# !tree
# Out:
# .
# └── my_file.txt
#
# 0 directories, 1 file

# %%
# !tree /root
# Out:
# /root
#
# 0 directories, 0 files

# %%
# !mkdir folder1

# %%
# !mkdir folder2

# %%
# !mkdir folder1/folder3

# %%
# !tree
# Out:
# .
# ├── folder1
# │   └── folder3
# ├── folder2
# └── my_file.txt
#
# 3 directories, 1 file

# %%
# !ls
# !pwd
# !mkdir
# !rm
# !cd

# %%
cd folder1
# Out:
# /content/folder1

# %%
# !tree
# Out:
# .
# └── folder3
#
# 1 directory, 0 files

# %%
# !touch file1.txt

# %%
# !touch folder3/file3.txt

# %%
# !tree
# Out:
# .
# ├── file1.txt
# └── folder3
#     └── file3.txt
#
# 1 directory, 2 files

# %%
cd .
# Out:
# /content/folder1

# %%
cd ..
# Out:
# /content

# %%
# !tree
# Out:
# .
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# └── my_file.txt
#
# 3 directories, 3 files

# %%
cd folder2
# Out:
# /content/folder2

# %%
# !tree
# Out:
# .
#
# 0 directories, 0 files

# %%
# !touch file2.txt

# %%
# !tree
# Out:
# .
# └── file2.txt
#
# 0 directories, 1 file

# %%
cd ..
# Out:
# /content

# %%
# !tree
# Out:
# .
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# │   └── file2.txt
# └── my_file.txt
#
# 3 directories, 4 files

# %%
# !pwd
# Out:
# /content

# %%
cd folder2
# Out:
# /content/folder2

# %%
# !pwd
# Out:
# /content/folder2

# %%
# !ls
# Out:
# file2.txt

# %%
cat file2.txt

# %%
# !nano file2.txt
# Out:
# /bin/bash: line 1: nano: command not found

# %%
# !sudo apt install nano
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   hunspell
# The following NEW packages will be installed:
#   nano
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 280 kB of archives.
# After this operation, 881 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 nano amd64 6.2-1 [280 kB]
# Fetched 280 kB in 0s (2,994 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nano.
# ...

# %%
# !echo "Hi File, from echo!" >> file2.txt

# %%
# !cat file2.txt
# Out:
# Hi File, from echo!

# %%
# !cd ..

# %%
# !pwd
# Out:
# /content

# %%
# !cat file2.txt
# Out:
# Hi File, from echo!

# %%
# !less file2.txt

# %%
# !pwd && whoami;
# Out:
# /content
# root

# %%
# !ls
# Out:
# file2.txt  folder1  folder2  my_file.txt

# %%
cd ../
# Out:
# /

# %%
# !ls
# Out:
# bin			    etc     media		      root  tools
# boot			    home    mnt			      run   usr
# content			    lib     NGC-DL-CONTAINER-LICENSE  sbin  var
# cuda-keyring_1.0-1_all.deb  lib32   opt			      srv
# datalab			    lib64   proc		      sys
# dev			    libx32  python-apt		      tmp

# %%
# !cd content
# Out:
# /bin/bash: line 1: cd: content: No such file or directory

# %%
# !touch text_empty.tsv

# %%
# !ls
# Out:
# file2.txt  folder1  folder2  my_file.txt  text_empty.tsv

# %%
# !mkdir one_more_folder

# %%
# !ls
# Out:
# file2.txt  folder1  folder2  my_file.txt  one_more_folder  text_empty.tsv

# %%
# !rm text_empty.tsv

# %%
# !touch one_more_folder/2.txt

# %%
# !tree
# Out:
# .
# ├── file2.txt
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# │   └── file2.txt
# ├── my_file.txt
# └── one_more_folder
#     └── 2.txt
#
# 4 directories, 6 files

# %%
# !rm one_more_folder
# Out:
# rm: cannot remove 'one_more_folder': Is a directory

# %%
# !rmdir one_more_folder
# Out:
# rmdir: failed to remove 'one_more_folder': Directory not empty

# %%
# !mkdir one_more_empty

# %%
# !tree
# Out:
# .
# ├── file2.txt
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# │   └── file2.txt
# ├── my_file.txt
# ├── one_more_empty
# └── one_more_folder
#     └── 2.txt
#
# 5 directories, 6 files

# %%
# !rmdir one_more_empty

# %%
# !tree
# Out:
# .
# ├── file2.txt
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# │   └── file2.txt
# ├── my_file.txt
# └── one_more_folder
#     └── 2.txt
#
# 4 directories, 6 files

# %%
# !rmdir folder2
# Out:
# rmdir: failed to remove 'folder2': Directory not empty

# %%
# !mkdir folder2 & touch folder2/file5.txt
# Out:
# mkdir: cannot create directory ‘folder2’: File exists

# %%
# !rm -rf folder2

# %%
# !tree
# Out:
# .
# ├── file2.txt
# ├── folder1
# │   ├── file1.txt
# │   └── folder3
# │       └── file3.txt
# ├── folder2
# │   ├── file2.txt
# │   ├── file4.txt
# │   └── file5.txt
# ├── my_file.txt
# ├── one_more_folder
# │   └── 2.txt
# └── touch
#
# 6 directories, 7 files

# %%
# !rm -rf /
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-2f4e812b48e9> in <cell line: 1>()
# ----> 1 get_ipython().system('rm -rf /')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#
# /usr/lib/python3.10/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#
# ...

# %%
# !rm -rf --no-preserve-root /
# Out:
# Streaming output truncated to the last 5000 lines.
# rm: cannot remove '/sys/devices/system/cpu/cpuidle/current_governor': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/uevent': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/hotplug/states': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/possible': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/offline': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/present': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/power/runtime_active_time': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/power/runtime_status': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/power/autosuspend_delay_ms': Read-only file system
# rm: cannot remove '/sys/devices/system/cpu/power/runtime_suspended_time': Read-only file system
# ...

# %%
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-64-7cb81ad7c064> in <cell line: 1>()
# ----> 1 get_ipython().system('ls')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#
# /usr/lib/python3.10/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#
# ...
